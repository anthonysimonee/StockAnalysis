# %% [markdown]
# <a href="https://colab.research.google.com/github/anthonysimonee/StockAnalysis/blob/main/CMPS_320_FinalProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Group 4 | Final Project Group Coding

# %%
import pandas as pd

# %% [markdown]
# Read in the csv files as singular dataframes.*italicized text*

# %%
df_3 = pd.read_csv("Sample_3.csv")

df_4 = pd.read_csv("Sample_4.csv")

df_5 = pd.read_csv("Sample_5_corrected.csv")

# %%
print(df_3.shape, df_4.shape, df_5.shape)
# Out:
# (370, 22) (340, 20) (305, 21)

# %% [markdown]
# ### Now we need to clean the data amungst all of the dataframes so we can combine the data smoothly.
#
# - Swap 'female' and 'age' columns in df_4
# - Drop 'chest', 'ethnicity', 'p_id' from all dataframes
# - Concatinate all of the data along rows

# %%
#DF 3 EDIT
df_3.drop('chest', axis=1, inplace=True)
df_3.drop('ethnicity', axis=1, inplace=True)
df_3.drop('p_id', axis=1, inplace=True)
df_3.head()
# Out:
#    age  female  grip  hex_5  hex_11  hex_17  hex_23  hex_29  hex_35  hex_41  \
# 0   23       0  34.0      1       3       3       1       1       1       3
# 1   19       0  30.0      4       4       2       1       3       2       4
# 2   18       1  20.0      4       5       4       5       4       2       2
# 3   19       0  38.0      2       1       2       3       4       5       4
# 4   19       0  39.0      3       2       4       2       2       3       4
#
#    hex_47  hex_53  hex_59  hex_65  hex_71  hex_77  hex_83  hex_89  hex_95
# 0       1       4       1       3       3       3       3       4       1
# 1       5       3       4       1       5       4       3       5       3
# 2       5       1       2       4       5       2       4       1       1
# 3       4       2       5       2       3       4       2       4       4
# 4       3       2       1       4       4       4       4       2       3

# %%
#DF 4 EDIT
df_4.drop('p_id', axis=1, inplace=True)
df_4[['age', 'female']] = df_4[['female', 'age']]
df_4.rename(columns={'age': 'temp_column', 'female': 'age'}, inplace=True)
df_4.rename(columns={'temp_column': 'female'}, inplace=True)

df_4.head()
# Out:
#     age  female   grip  hex_5  hex_11  hex_17  hex_23  hex_29  hex_35  hex_41  \
# 0  18.0       1  29.32    3.0       5       5       5       3       5       4
# 1  21.0       1  23.55    4.0       4       4       5       4       4       2
# 2  18.0       1  31.18    5.0       2       5       2       2       1       1
# 3  19.0       1  23.91    2.0       4       4       2       2       4       1
# 4  19.0       0  39.09    2.0       4       2       2       2       3       3
#
#    hex_47  hex_53  hex_59  hex_65  hex_71  hex_77  hex_83  hex_89  hex_95
# 0       5     4.0     2.0       5     5.0     5.0       5       5       5
# 1       3     5.0     4.0       2     3.0     2.0       4       1       3
# 2       4     2.0     1.0       4     4.0     3.0       5       4       2
# 3       4     2.0     5.0       3     5.0     4.0       4       1       2
# 4       2     3.0     4.0       4     4.0     1.0       4       4       3

# %%
#DF 5 EDIT
df_5.drop('ethnicity', axis=1, inplace=True)
df_5.drop('p_id', axis=1, inplace=True)
df_5.head()
# Out:
#    age  female   grip  hex_5  hex_11  hex_17  hex_23  hex_29  hex_35  hex_41  \
# 0   18       0  36.40      4       4       2       2       4       2       4
# 1   20       0  34.24      2       2       4       5       4       2       3
# 2   18       0  38.86      3       3       3       3       3       3       3
# 3   19       0  33.69      4       4       3       3       3       2       3
# 4   19       0  47.53      2       4       2       4       3       3       4
#
#    hex_47  hex_53  hex_59  hex_65  hex_71  hex_77  hex_83  hex_89  hex_95
# 0       4       2       4       4       2       2       4       3       4
# 1       5       5       1       2       5       2       3       5       1
# 2       3       3       3       3       3       3       3       3       3
# 3       4       3       5       2       4       2       4       5       2
# 4       4       3       4       3       4       3       3       3       3

# %%
#Combine Dataset
combined_df = pd.concat([df_3, df_4, df_5], ignore_index=True)
combined_df.head()
# Out:
#     age  female  grip  hex_5  hex_11  hex_17  hex_23  hex_29  hex_35  hex_41  \
# 0  23.0       0  34.0    1.0       3       3       1       1       1       3
# 1  19.0       0  30.0    4.0       4       2       1       3       2       4
# 2  18.0       1  20.0    4.0       5       4       5       4       2       2
# 3  19.0       0  38.0    2.0       1       2       3       4       5       4
# 4  19.0       0  39.0    3.0       2       4       2       2       3       4
#
#    hex_47  hex_53  hex_59  hex_65  hex_71  hex_77  hex_83  hex_89  hex_95
# 0       1     4.0     1.0       3     3.0     3.0       3       4       1
# 1       5     3.0     4.0       1     5.0     4.0       3       5       3
# 2       5     1.0     2.0       4     5.0     2.0       4       1       1
# 3       4     2.0     5.0       2     3.0     4.0       2       4       4
# 4       3     2.0     1.0       4     4.0     4.0       4       2       3

# %%
combined_df.shape
# Out:
# (1015, 19)

# %% [markdown]
# ### Standardizing the Data

# %%
def standardizeData(data):
    from sklearn.preprocessing import MinMaxScaler

    # Create a StandardScaler object
    scaler = MinMaxScaler()

    # Fit the scaler to data
    scaler.fit(data)

    # Transform data using the scaler to standardize it, return as DataFrame
    return pd.DataFrame(scaler.transform(data))

# %%
X = combined_df.drop("grip", axis = 1)

y = combined_df["grip"]

column_names = X.columns.tolist()

X = standardizeData(X)

X.columns = column_names

X.head()
# Out:
#     age  female  hex_5  hex_11  hex_17  hex_23  hex_29  hex_35  hex_41  \
# 0  0.25     0.0   0.00    0.50    0.50    0.00    0.00    0.00    0.50
# 1  0.05     0.0   0.75    0.75    0.25    0.00    0.50    0.25    0.75
# 2  0.00     1.0   0.75    1.00    0.75    1.00    0.75    0.25    0.25
# 3  0.05     0.0   0.25    0.00    0.25    0.50    0.75    1.00    0.75
# 4  0.05     0.0   0.50    0.25    0.75    0.25    0.25    0.50    0.75
#
#    hex_47  hex_53  hex_59  hex_65  hex_71  hex_77  hex_83  hex_89  hex_95
# 0    0.00    0.75    0.00    0.50    0.50    0.50    0.50    0.75    0.00
# 1    1.00    0.50    0.75    0.00    1.00    0.75    0.50    1.00    0.50
# 2    1.00    0.00    0.25    0.75    1.00    0.25    0.75    0.00    0.00
# 3    0.75    0.25    1.00    0.25    0.50    0.75    0.25    0.75    0.75
# 4    0.50    0.25    0.00    0.75    0.75    0.75    0.75    0.25    0.50

# %% [markdown]
# | THINGS TO DO |
#
# - Assign Roles
#
#   - Eli (random forest model)
#   - Ant (begin presentation & final report)
#   - Nick (k-means model)
#   - Claudia (begin presentation & final report)
#   - Andrew (begin presentation & final report)
#
#   We will figure out more coding roles and fine tuning later in the project
